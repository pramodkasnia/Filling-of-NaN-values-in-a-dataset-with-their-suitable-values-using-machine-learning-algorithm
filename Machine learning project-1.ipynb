# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Prestige_miss.csv")
df
# Out:
#      education   income  women  prestige  census  type
# 0        13.11  12351.0  11.16      68.8  1113.0  prof
# 1        12.26  25879.0   4.02      69.1  1130.0  prof
# 2        12.77   9271.0  15.70      63.4  1171.0  prof
# 3        11.42      NaN   9.11      56.8  1175.0  prof
# 4        14.62   8403.0  11.68      73.5  2111.0  prof
# 5        15.64  11030.0   5.13      77.6  2113.0   NaN
# 6        15.09   8258.0  25.65      72.6  2133.0  prof
# 7          NaN  14163.0   2.69      78.1  2141.0  prof
# 8        14.52  11377.0   1.03      73.1  2143.0  prof
# 9        14.64  11023.0   0.94      68.8  2153.0  prof
# 10       12.39      NaN   1.91      62.0  2161.0  prof
# 11         NaN   7059.0   7.83      60.0  2163.0  prof
# 12       13.83   8425.0  15.33      53.8  2183.0  prof
# 13       14.44   8049.0  57.31      62.2  2311.0  prof
# 14       14.36   7405.0  48.28      74.9  2315.0  prof
# 15       14.21   6336.0  54.77      55.1  2331.0  prof
# ...

# %%
mask1=df["education"].isnull()
mask2=df["income"].isnull()
mask3=df["women"].isnull()
mask4=df["prestige"].isnull()
mask5=df["census"].isnull()
mask6=df["type"].isnull()

# %%
df2=df.copy()

# %%
df2.dropna(axis=0,inplace=True)

# %%
df2
# Out:
#      education   income  women  prestige  census  type
# 0        13.11  12351.0  11.16      68.8  1113.0  prof
# 1        12.26  25879.0   4.02      69.1  1130.0  prof
# 2        12.77   9271.0  15.70      63.4  1171.0  prof
# 4        14.62   8403.0  11.68      73.5  2111.0  prof
# 6        15.09   8258.0  25.65      72.6  2133.0  prof
# 8        14.52  11377.0   1.03      73.1  2143.0  prof
# 9        14.64  11023.0   0.94      68.8  2153.0  prof
# 12       13.83   8425.0  15.33      53.8  2183.0  prof
# 13       14.44   8049.0  57.31      62.2  2311.0  prof
# 14       14.36   7405.0  48.28      74.9  2315.0  prof
# 15       14.21   6336.0  54.77      55.1  2331.0  prof
# 16       15.77  19263.0   5.13      82.3  2343.0  prof
# 18       15.22   9593.0  34.89      58.3  2391.0  prof
# 19       14.50   4686.0   4.14      72.8  2511.0  prof
# 20       15.97  12480.0  19.59      84.6  2711.0  prof
# 22       15.08   8034.0  46.80      66.1  2733.0  prof
# ...

# %%
# Out:
#     education   income  women  prestige  census  type
# 3       11.42      NaN   9.11      56.8  1175.0  prof
# 5       15.64  11030.0   5.13      77.6  2113.0   NaN
# 7         NaN  14163.0   2.69      78.1  2141.0  prof
# 10      12.39      NaN   1.91      62.0  2161.0  prof
# 11        NaN   7059.0   7.83      60.0  2163.0  prof
# 17      14.15   6112.0  77.10       NaN  2351.0  prof
# 21      13.62   5648.0  83.78      59.6     NaN  prof
# 27       9.45   3485.0  76.14      34.9     NaN    bc
# 30        NaN   5180.0  76.04      67.5  3156.0    wc
# 31      11.09   6197.0    NaN      57.2  3314.0  prof
# 32      12.71   7562.0  11.15       NaN  3337.0    wc
# 33      11.44   8206.0   8.13      54.1  3373.0   NaN
# 35      11.49   3148.0  95.97      41.9     NaN    wc
# 37        NaN   2448.0  91.76      42.3  4133.0    wc
# 41      11.04   2901.0  92.86      38.7     NaN    wc
# 42       9.22      NaN   7.62      36.1  4172.0    wc
# ...

# %% [markdown]
# ## For finding missing values of "prestige"

# %%
X=df2.iloc[:,[0,1,2,4]]
Y=df2.iloc[:,3]
X_Test=df[mask4].iloc[:,[0,1,2,4]]

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.predict(X_Test)
# Out:
# array([60.29292624, 55.32573672, 34.34609921])

# %%
df.at[17, 'prestige']=60.2929
df.at[32, 'prestige']=55.3257
df.at[52, 'prestige']=34.3460

# %%
mask4=df["prestige"].isnull()
df[mask4]
df
# Out:
#      education   income  women  prestige  census  type
# 0        13.11  12351.0  11.16   68.8000  1113.0  prof
# 1        12.26  25879.0   4.02   69.1000  1130.0  prof
# 2        12.77   9271.0  15.70   63.4000  1171.0  prof
# 3        11.42      NaN   9.11   56.8000  1175.0  prof
# 4        14.62   8403.0  11.68   73.5000  2111.0  prof
# 5        15.64  11030.0   5.13   77.6000  2113.0   NaN
# 6        15.09   8258.0  25.65   72.6000  2133.0  prof
# 7          NaN  14163.0   2.69   78.1000  2141.0  prof
# 8        14.52  11377.0   1.03   73.1000  2143.0  prof
# 9        14.64  11023.0   0.94   68.8000  2153.0  prof
# 10       12.39      NaN   1.91   62.0000  2161.0  prof
# 11         NaN   7059.0   7.83   60.0000  2163.0  prof
# 12       13.83   8425.0  15.33   53.8000  2183.0  prof
# 13       14.44   8049.0  57.31   62.2000  2311.0  prof
# 14       14.36   7405.0  48.28   74.9000  2315.0  prof
# 15       14.21   6336.0  54.77   55.1000  2331.0  prof
# ...

# %% [markdown]
# ## For findind ,issing values of "income"

# %%
df3=df.copy()
df3.dropna(axis=0,inplace=True)
X=df3.iloc[:,[0,2,3,4]]
Y=df3.iloc[:,1]
X_Test=df[mask2].iloc[:,[0,2,3,4]]
import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.predict(X_Test)
# Out:
# array([10792.21579666, 11807.94068961,  6968.39218727,  6284.8194963 ,
#         8491.30669765])

# %%
df.at[3, 'income']=10792.21
df.at[10, 'income']=11807.94
df.at[42, 'income']=6968.39
df.at[46, 'income']=6284.81
df.at[96, 'income']=8491.30

# %% [markdown]
# ## For finding missing values of "women"

# %%
df4=df.copy()
df4.dropna(axis=0,inplace=True)
X=df4.iloc[:,[0,1,3,4]]
Y=df4.iloc[:,2]
X_Test=df[mask3].iloc[:,[0,1,3,4]]
import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, Y)
reg.predict(X_Test)
# Out:
# array([38.81182698, 43.72601499, 41.35431434, 32.5408171 , 15.7618447 ,
#        19.68612852])

# %%
df.at[31, 'women']=38.81
df.at[43, 'women']=43.72
df.at[45, 'women']=41.35
df.at[60, 'women']=32.54
df.at[84, 'women']=15.76
df.at[98, 'women']=19.68

# %% [markdown]
# ## Fr finding missing values of "census"

# %%
df5=df.copy()
df5.dropna(axis=0,inplace=True)
X=df5.iloc[:,[0,1,2,3]]
Y=df5.iloc[:,4]
X_Test=df[mask5].iloc[:,[0,1,2,3]]
import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, Y)
reg.predict(X_Test)
# Out:
# array([2469.39584618, 5791.98896661, 3821.20738181, 4199.14267854,
#        8244.7875156 ])

# %%
df.at[21, 'census']=2469.39
df.at[27, 'census']=5791.98
df.at[35, 'census']=3821.20
df.at[41, 'census']=4199.14
df.at[83, 'census']=8244.78

# %% [markdown]
# ## For finding missing values of "education"

# %%
df6=df.copy()
df6.dropna(axis=0,inplace=True)
X=df6.iloc[:,[1,2,3,4]]
Y=df6.iloc[:,0]
X_Test=df[mask1].iloc[:,[1,2,3,4]]
import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, Y)
reg.predict(X_Test)
# Out:
# array([15.09677414, 13.46499177, 13.86668649, 11.13202114,  8.92824977,
#         7.95146229,  7.61780049])

# %%
df.at[7, 'education']=15.09
df.at[11, 'education']=13.46
df.at[30, 'education']=13.86
df.at[37, 'education']=11.13
df.at[59, 'education']=8.92
df.at[65, 'education']=7.95
df.at[67, 'education']=7.61

# %% [markdown]
# ## For finding missing values of "type"

# %%
df7=df.copy()
df7.dropna(axis=0,inplace=True)
X=df7.iloc[:,[0,1,2,3,4]]
Y=df7.iloc[:,5]
X_Test=df[mask6].iloc[:,[0,1,2,3,4]]
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier() 
classifier=classifier.fit(X, Y) 
classifier.predict(X_Test)
# Out:
# array(['prof', 'wc', 'wc', 'wc', 'wc', 'bc', 'bc', 'bc'], dtype=object)

# %%
df.at[5, 'type']='prof'
df.at[33, 'type']='wc'
df.at[44, 'type']='wc'
df.at[52, 'type']='wc'
df.at[54, 'type']='wc'
df.at[62, 'type']='bc'
df.at[66, 'type']='bc'
df.at[68, 'type']='bc'

# %%
df
# Out:
#      education    income  women  prestige   census  type
# 0        13.11  12351.00  11.16   68.8000  1113.00  prof
# 1        12.26  25879.00   4.02   69.1000  1130.00  prof
# 2        12.77   9271.00  15.70   63.4000  1171.00  prof
# 3        11.42  10792.21   9.11   56.8000  1175.00  prof
# 4        14.62   8403.00  11.68   73.5000  2111.00  prof
# 5        15.64  11030.00   5.13   77.6000  2113.00  prof
# 6        15.09   8258.00  25.65   72.6000  2133.00  prof
# 7        15.09  14163.00   2.69   78.1000  2141.00  prof
# 8        14.52  11377.00   1.03   73.1000  2143.00  prof
# 9        14.64  11023.00   0.94   68.8000  2153.00  prof
# 10       12.39  11807.94   1.91   62.0000  2161.00  prof
# 11       13.46   7059.00   7.83   60.0000  2163.00  prof
# 12       13.83   8425.00  15.33   53.8000  2183.00  prof
# 13       14.44   8049.00  57.31   62.2000  2311.00  prof
# 14       14.36   7405.00  48.28   74.9000  2315.00  prof
# ...
